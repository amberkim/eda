# %% [markdown]
# # Health Burden

# %% [markdown]
# ## Set up

# %%
# Read in data
import pandas
data = pandas.read_csv('./data/prepped/risk-data.csv')

# %% [markdown]
# ## Data Structure
# To get a basic sense of your dataset, check the following:
#
# - How large is the dataset (rows, columns)?
# - What are the variables present in the dataset?
# - What is the data type of each variable?

# %%
# dataset size
shape = data.shape
print("rows=%d, cols=%d" % shape)
print()

# variables present in dataset
names = data.columns.values
print('Column names:')
print(names)
print()

# data types of variables
dtypes = data.dtypes
print('Data types:')
print(dtypes)
# Out:
# rows=1950, cols=12
#
# Column names:
# ['country' 'country.code' 'super.region' 'region' 'sex' 'age' 'pop'
#  'alcohol.use' 'drug.use' 'high.meat' 'low.exercise' 'smoking']
#
# Data types:
# country          object
# country.code     object
# super.region     object
# region           object
# sex              object
# age              object
# pop             float64
# alcohol.use     float64
# drug.use        float64
# high.meat       float64
# low.exercise    float64
# smoking         float64
# dtype: object

# %% [markdown]
# ## Univariate Analysis
# For each variable of interest, answer the following questions. As you do so, begin making a list of further questions you would like to investigate:
#
# - What does the distribution of each (risk factor) variable look like?
# - Is any variable ever missing (and if so, why)?
# - What are the basic summary statistics (mean, median, standard deviation) each variable, and what is it's range (min/max)?
# - What do you find surprising?

# %%
# import plotly to graph distributions
from plotly.offline import plot
import plotly.graph_objs as go

alc_data = [go.Histogram(
    x=data.get('alcohol.use'),
)]

drug_data = [go.Histogram(
    x=data.get('drug.use'),
)]

meat_data = [go.Histogram(
    x=data.get('high.meat'),
)]

exc_data = [go.Histogram(
    x=data.get('low.exercise'),
)]

# plot data
plot(alc_data)
plot(drug_data)
plot(meat_data)
plot(exc_data)
# Out:
# 'file:///Users/amberkim/Google Drive (uw)/INFO 370/eda/health-burden/temp-plot.html'

# %%
# any missing variables
#data.isnull()
missing = data['high.meat'].isnull()
data[missing]
# Out:
#                     country country.code  \
# 2                     China          CHN
# 3                     China          CHN
# 6                     China          CHN
# 8                     China          CHN
# 10              North Korea          PRK
# 11              North Korea          PRK
# 15              North Korea          PRK
# 18              North Korea          PRK
# 23                   Taiwan          TWN
# 26                   Taiwan          TWN
# 28                   Taiwan          TWN
# 29                   Taiwan          TWN
# 32                 Cambodia          KHM
# 36                 Cambodia          KHM
# 38                 Cambodia          KHM
# 39                 Cambodia          KHM
# 40                Indonesia          IDN
# 41                Indonesia          IDN
# 42                Indonesia          IDN
# 47                Indonesia          IDN
# 56                     Laos          LAO
# 57                     Laos          LAO
# 58                     Laos          LAO
# 59                     Laos          LAO
# 60                 Malaysia          MYS
# 61                 Malaysia          MYS
# 63                 Malaysia          MYS
# 65                 Malaysia          MYS
# 75                 Maldives          MDV
# 77                 Maldives          MDV
# ...                     ...          ...
# 1873                   Mali          MLI
# 1875                   Mali          MLI
# 1884             Mauritania          MRT
# 1886             Mauritania          MRT
# 1887             Mauritania          MRT
# 1888             Mauritania          MRT
# 1891                  Niger          NER
# 1893                  Niger          NER
# 1894                  Niger          NER
# 1896                  Niger          NER
# 1904                Nigeria          NGA
# 1906                Nigeria          NGA
# 1907                Nigeria          NGA
# 1908                Nigeria          NGA
# 1911  Sao Tome and Principe          STP
# 1913  Sao Tome and Principe          STP
# 1914  Sao Tome and Principe          STP
# 1916  Sao Tome and Principe          STP
# 1924                Senegal          SEN
# 1926                Senegal          SEN
# 1927                Senegal          SEN
# 1929                Senegal          SEN
# 1930           Sierra Leone          SLE
# 1933           Sierra Leone          SLE
# 1935           Sierra Leone          SLE
# 1936           Sierra Leone          SLE
# 1941                   Togo          TGO
# 1943                   Togo          TGO
# 1945                   Togo          TGO
# 1946                   Togo          TGO
#
#                                 super.region                      region  \
# 2     Southeast Asia, East Asia, and Oceania                   East Asia
# 3     Southeast Asia, East Asia, and Oceania                   East Asia
# 6     Southeast Asia, East Asia, and Oceania                   East Asia
# 8     Southeast Asia, East Asia, and Oceania                   East Asia
# 10    Southeast Asia, East Asia, and Oceania                   East Asia
# 11    Southeast Asia, East Asia, and Oceania                   East Asia
# 15    Southeast Asia, East Asia, and Oceania                   East Asia
# 18    Southeast Asia, East Asia, and Oceania                   East Asia
# 23    Southeast Asia, East Asia, and Oceania                   East Asia
# 26    Southeast Asia, East Asia, and Oceania                   East Asia
# 28    Southeast Asia, East Asia, and Oceania                   East Asia
# 29    Southeast Asia, East Asia, and Oceania                   East Asia
# 32    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 36    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 38    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 39    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 40    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 41    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 42    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 47    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 56    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 57    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 58    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 59    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 60    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 61    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 63    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 65    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 75    Southeast Asia, East Asia, and Oceania              Southeast Asia
# 77    Southeast Asia, East Asia, and Oceania              Southeast Asia
# ...                                      ...                         ...
# 1873                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1875                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1884                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1886                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1887                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1888                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1891                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1893                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1894                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1896                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1904                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1906                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1907                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1908                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1911                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1913                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1914                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1916                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1924                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1926                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1927                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1929                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1930                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1933                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1935                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1936                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1941                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1943                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1945                      Sub-Saharan Africa  Western Sub-Saharan Africa
# 1946                      Sub-Saharan Africa  Western Sub-Saharan Africa
#
#          sex         age           pop  alcohol.use  drug.use  high.meat  \
# 2       male     Under 5  4.458679e+07     0.236908  0.120827        NaN
# 3       male  5-14 years  8.299538e+07     1.292633  0.038498        NaN
# 6     female  5-14 years  7.148107e+07     0.868670  0.039037        NaN
# 8     female     Under 5  3.854704e+07     0.183050  0.126190        NaN
# 10      male     Under 5  8.955102e+05     0.186889  0.101431        NaN
# 11    female     Under 5  8.553315e+05     0.195622  0.109240        NaN
# 15      male  5-14 years  1.826308e+06     1.078984  0.029139        NaN
# 18    female  5-14 years  1.751028e+06     0.709501  0.028816        NaN
# 23      male  5-14 years  1.278556e+06     0.605018  0.006473        NaN
# 26    female  5-14 years  1.167340e+06     0.424741  0.005962        NaN
# 28      male     Under 5  5.332155e+05     0.146763  0.023686        NaN
# 29    female     Under 5  4.875142e+05     0.150790  0.032121        NaN
# 32    female  5-14 years  1.548923e+06     0.382470  0.172875        NaN
# 36      male     Under 5  9.109717e+05     0.296777  0.460341        NaN
# 38      male  5-14 years  1.602495e+06     0.845309  0.146689        NaN
# 39    female     Under 5  8.751491e+05     0.274487  0.546200        NaN
# 40      male  5-14 years  2.390000e+07     0.166115  0.038020        NaN
# 41    female     Under 5  1.215305e+07     0.014568  0.245807        NaN
# 42      male     Under 5  1.264684e+07     0.022938  0.259538        NaN
# 47    female  5-14 years  2.250000e+07     0.062695  0.035421        NaN
# 56    female  5-14 years  7.484250e+05     0.508396  0.002537        NaN
# 57      male     Under 5  4.258995e+05     0.393618  0.011466        NaN
# 58      male  5-14 years  7.778120e+05     0.904358  0.003109        NaN
# 59    female     Under 5  4.101430e+05     0.405594  0.011983        NaN
# 60      male     Under 5  1.255658e+06     0.033275  0.172330        NaN
# 61      male  5-14 years  2.409461e+06     0.149386  0.168960        NaN
# 63    female     Under 5  1.185833e+06     0.037138  0.177175        NaN
# 65    female  5-14 years  2.546436e+06     0.066807  0.169868        NaN
# 75    female  5-14 years  3.044700e+04     0.092604  0.007189        NaN
# 77      male     Under 5  1.926674e+04     0.046948  0.017120        NaN
# ...      ...         ...           ...          ...       ...        ...
# 1873    male  5-14 years  2.602835e+06     0.151282  0.162847        NaN
# 1875  female     Under 5  1.591175e+06     0.082074  0.340904        NaN
# 1884  female  5-14 years  5.057170e+05     0.014741  0.073656        NaN
# 1886    male     Under 5  3.152460e+05     0.012945  0.013295        NaN
# 1887  female     Under 5  3.029862e+05     0.010542  0.016521        NaN
# 1888    male  5-14 years  5.208940e+05     0.025807  0.070350        NaN
# 1891  female  5-14 years  2.882715e+06     0.070706  0.144580        NaN
# 1893    male     Under 5  2.092790e+06     0.045685  0.078472        NaN
# 1894    male  5-14 years  3.014736e+06     0.106059  0.136633        NaN
# 1896  female     Under 5  2.006993e+06     0.036360  0.085548        NaN
# 1904  female  5-14 years  2.390000e+07     0.316547  1.013988        NaN
# 1906    male     Under 5  1.604768e+07     0.357212  1.936762        NaN
# 1907  female     Under 5  1.528964e+07     0.337678  2.097706        NaN
# 1908    male  5-14 years  2.520000e+07     0.479977  0.959434        NaN
# 1911  female  5-14 years  2.559600e+04     0.295006  0.000099        NaN
# 1913    male     Under 5  1.533721e+04     0.539853  0.002275        NaN
# 1914    male  5-14 years  2.596700e+04     0.653128  0.000106        NaN
# 1916  female     Under 5  1.495766e+04     0.368042  0.003510        NaN
# 1924  female  5-14 years  1.987082e+06     0.108259  0.074757        NaN
# 1926    male     Under 5  1.308494e+06     0.076087  0.114549        NaN
# 1927    male  5-14 years  2.032493e+06     0.186868  0.070512        NaN
# 1929  female     Under 5  1.272743e+06     0.060337  0.123972        NaN
# 1930    male     Under 5  5.083643e+05     0.612461  0.087391        NaN
# 1933  female  5-14 years  8.675780e+05     0.664601  0.078851        NaN
# 1935    male  5-14 years  8.619320e+05     0.903488  0.076930        NaN
# 1936  female     Under 5  5.049774e+05     0.632909  0.092871        NaN
# 1941  female  5-14 years  9.601530e+05     0.238532  0.480699        NaN
# 1943    male  5-14 years  9.652130e+05     0.397258  0.454347        NaN
# 1945  female     Under 5  5.764667e+05     0.121739  0.278622        NaN
# 1946    male     Under 5  5.816957e+05     0.144637  0.260161        NaN
#
#       low.exercise  smoking
# 2              NaN      NaN
# 3              NaN      NaN
# 6              NaN      NaN
# 8              NaN      NaN
# 10             NaN      NaN
# 11             NaN      NaN
# 15             NaN      NaN
# 18             NaN      NaN
# 23             NaN      NaN
# 26             NaN      NaN
# 28             NaN      NaN
# 29             NaN      NaN
# 32             NaN      NaN
# 36             NaN      NaN
# 38             NaN      NaN
# 39             NaN      NaN
# 40             NaN      NaN
# 41             NaN      NaN
# 42             NaN      NaN
# 47             NaN      NaN
# 56             NaN      NaN
# 57             NaN      NaN
# 58             NaN      NaN
# 59             NaN      NaN
# 60             NaN      NaN
# 61             NaN      NaN
# 63             NaN      NaN
# 65             NaN      NaN
# 75             NaN      NaN
# 77             NaN      NaN
# ...            ...      ...
# 1873           NaN      NaN
# 1875           NaN      NaN
# 1884           NaN      NaN
# 1886           NaN      NaN
# 1887           NaN      NaN
# 1888           NaN      NaN
# 1891           NaN      NaN
# 1893           NaN      NaN
# 1894           NaN      NaN
# 1896           NaN      NaN
# 1904           NaN      NaN
# 1906           NaN      NaN
# 1907           NaN      NaN
# 1908           NaN      NaN
# 1911           NaN      NaN
# 1913           NaN      NaN
# 1914           NaN      NaN
# 1916           NaN      NaN
# 1924           NaN      NaN
# 1926           NaN      NaN
# 1927           NaN      NaN
# 1929           NaN      NaN
# 1930           NaN      NaN
# 1933           NaN      NaN
# 1935           NaN      NaN
# 1936           NaN      NaN
# 1941           NaN      NaN
# 1943           NaN      NaN
# 1945           NaN      NaN
# 1946           NaN      NaN
#
# [780 rows x 12 columns]

# %%
# summary statistics for each variable
print(data.describe())
print()
print('medians: ')
print(data.median())
# Out:
#                 pop  alcohol.use     drug.use    high.meat  low.exercise  \
# count  1.950000e+03  1950.000000  1950.000000  1170.000000   1170.000000
# mean   3.777708e+06    47.146545     7.128357     2.594225    119.552443
# std    1.913391e+07    86.009150    14.197640     4.043355    153.239610
# min    3.563755e+02  -106.232008     0.000038     0.000176      0.308731
# 25%    1.000900e+05     0.273705     0.030068          NaN           NaN
# 50%    5.054975e+05     6.784878     1.917572          NaN           NaN
# 75%    2.071966e+06    54.987255     8.528416          NaN           NaN
# max    3.901690e+08   662.914151   314.625888    36.087746    844.249502
#
#            smoking
# count  1170.000000
# mean    299.520438
# std     437.167168
# min       0.532166
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max    2691.239677
#
# medians:
# pop             505497.500000
# alcohol.use          6.784878
# drug.use             1.917572
# high.meat            0.817486
# low.exercise        40.743931
# smoking            105.816725
# dtype: float64
# //anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning:
#
# Invalid value encountered in percentile

# %% [markdown]
# ## Univariate analysis (by age)
# In this section, you should investigate how each (risk-variable) varies by **age group**. More specifically, consider if the distribution of each variable of interest (smoking, alcohol use, etc.) is consistent across age-groups.

# %%
# Code goes here

# %% [markdown]
# ## Univariate analysis (by sex)
# In this section, you should investigate how each (risk-variable) varies by **sex group**. More specifically, consider if the distribution of each variable of interest (smoking, alcohol use, etc.) is consistent across sex-groups. Depending on your procedure, you may need to **reshape your data**.

# %%
# Code goes here

# %% [markdown]
# ## Univariate analysis (by country)
# In this section, you should investigate how each (risk-variable) varies by **country**. Given the number of countries present in the dataset, I suggest that you aggregate your data by region. In order to do this, you'll need to **convert death rates to deaths** using the `pop` column.

# %%
# Code goes here

# %% [markdown]
# ## Bivariate analysis
# In this section, you should compare risks-variables to one another to see how they co-vary. Use simple statistical tests (i.e., **correlation**) and visualization as you see fit.

# %%
# Code goes here
